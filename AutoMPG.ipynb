# %%
import numpy as np

# %%
import pandas as pd

# %%
#delim_whitespace=True - it just separate dataset where there is whitespace
#sep = '\s+' - 
#delimiter = if there are special charater in dataset like , : . etc ... then its separate that position with whitespace...
auto  =  pd.read_csv(r"C:\Users\hp\Downloads\auto+mpg\auto-mpg.data",header=None,sep = '\s+')
auto
# Out:
#         0  1      2      3       4     5   6  7                          8
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
# ..    ... ..    ...    ...     ...   ...  .. ..                        ...
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1            ford mustang gl
# 394  44.0  4   97.0  52.00  2130.0  24.6  82  2                  vw pickup
# 395  32.0  4  135.0  84.00  2295.0  11.6  82  1              dodge rampage
# 396  28.0  4  120.0  79.00  2625.0  18.6  82  1                ford ranger
# 397  31.0  4  119.0  82.00  2720.0  19.4  82  1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
#Renaming hte columns(if required)
auto.columns = ['MPG','Cylinders','Displacements','Horsepower','Weight','Acceleration','ModelYear','Origin','Car Name']
auto.head()
# Out:
#     MPG  Cylinders  Displacements Horsepower  Weight  Acceleration  ModelYear  \
# 0  18.0          8          307.0      130.0  3504.0          12.0         70
# 1  15.0          8          350.0      165.0  3693.0          11.5         70
# 2  18.0          8          318.0      150.0  3436.0          11.0         70
# 3  16.0          8          304.0      150.0  3433.0          12.0         70
# 4  17.0          8          302.0      140.0  3449.0          10.5         70
#
#    Origin                   Car Name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#To check missing values
auto.isnull().sum()
# Out:
# MPG              0
# Cylinders        0
# Displacements    0
# Horsepower       0
# Weight           0
# Acceleration     0
# ModelYear        0
# Origin           0
# Car Name         0
# dtype: int64

# %%
#To check data types
auto.dtypes
# Out:
# MPG              float64
# Cylinders          int64
# Displacements    float64
# Horsepower        object
# Weight           float64
# Acceleration     float64
# ModelYear          int64
# Origin             int64
# Car Name          object
# dtype: object

# %%
#To check unique values
for i in auto.columns:
    print(i,':','\n',auto[i].unique(),'\n')
# Out:
# MPG :
#  [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
#
# Cylinders :
#  [8 4 6 3 5]
#
# Displacements :
#  [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
# ...

# %%
for i in auto.columns:
    print(i,':',sum(auto[i]=='?'))
# Out:
# MPG : 0
# Cylinders : 0
# Displacements : 0
# Horsepower : 6
# Weight : 0
# Acceleration : 0
# ModelYear : 0
# Origin : 0
# Car Name : 0

# %%
#describe 
d = auto.describe(include='all')
d
# Out:
#                MPG   Cylinders  Displacements Horsepower       Weight  \
# count   398.000000  398.000000     398.000000        398   398.000000
# unique         NaN         NaN            NaN         94          NaN
# top            NaN         NaN            NaN      150.0          NaN
# freq           NaN         NaN            NaN         22          NaN
# mean     23.514573    5.454774     193.425879        NaN  2970.424623
# std       7.815984    1.701004     104.269838        NaN   846.841774
# min       9.000000    3.000000      68.000000        NaN  1613.000000
# 25%      17.500000    4.000000     104.250000        NaN  2223.750000
# 50%      23.000000    4.000000     148.500000        NaN  2803.500000
# 75%      29.000000    8.000000     262.000000        NaN  3608.000000
# max      46.600000    8.000000     455.000000        NaN  5140.000000
#
#         Acceleration   ModelYear      Origin    Car Name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
auto.Horsepower.replace('?',d['Horsepower'][2],inplace = True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4160\391739936.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   auto.Horsepower.replace('?',d['Horsepower'][2],inplace = True)
# C:\Users\hp\AppData\Local\Temp\ipykernel_4160\391739936.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
for i in auto.columns:
    print(i,':','\n',sum(auto[i]=='?'))
# Out:
# MPG :
#  0
# Cylinders :
#  0
# Displacements :
#  0
# Horsepower :
#  0
# Weight :
#  0
# Acceleration :
#  0
# ModelYear :
#  0
# Origin :
#  0
# Car Name :
#  0

# %%
auto.Horsepower=auto.Horsepower.astype(float)
auto.dtypes
# Out:
# MPG              float64
# Cylinders          int64
# Displacements    float64
# Horsepower       float64
# Weight           float64
# Acceleration     float64
# ModelYear          int64
# Origin             int64
# Car Name          object
# dtype: object

# %%
#Data Visualization 

import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(auto.Cylinders) 
plt.show()

# %%
sns.histplot(data=auto,fill = True)
plt.show()

# %%
sns.kdeplot(data=auto,fill = True)
plt.show()

# %%
sns.boxplot(x=auto.MPG,y = auto.Cylinders,palette='bright') #palette changes the colour of the box.. 
plt.show()

# %%
sns.violinplot(x=auto.MPG,y = auto.Cylinders,palette='bright')  
plt.show()

# %%
sns.swarmplot(x=auto.MPG,y = auto.Cylinders,palette='bright')  #jahan pe jyada points wahan pe maximum value
plt.show()

# %%
sns.jointplot(x=auto.Displacements,y=auto.Horsepower,hue=auto.MPG)
plt.show()

# %%
sns.scatterplot(x=auto.Displacements,y=auto.Horsepower,hue=auto.Displacements)
plt.show()

# %%
sns.jointplot(x=auto.Weight,y=auto.Acceleration,hue=auto.MPG)
plt.show()

# %%
sns.scatterplot(x=auto.Weight,y=auto.Acceleration,hue=auto.Weight)
plt.show()

# %%
plt.figure(figsize=(20,15)) #It fix ovelap of number in x axis
sns.countplot(x=auto.ModelYear,palette='rocket')
plt.show()

# %%
plt.figure(figsize=(20,15)) #It fix ovelap of number in x axis
sns.countplot(x=auto.Origin,palette='rocket')
plt.show()

# %%
plt.figure(figsize=(15,25))
sns.boxplot(x = auto.MPG,y = auto['Car Name'],palette='bright')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
auto['Car Name']= le.fit_transform(auto['Car Name'])
auto['Car Name'].unique()
# Out:
# array([ 49,  36, 231,  14, 161, 141,  54, 223, 241,   1, 101, 215,  57,
#         30, 274, 220,   8, 150,  95, 282, 211,  16, 258,  22,   7, 133,
#         68, 112, 163,  65, 271, 156, 232, 162,  10, 242, 116, 129, 250,
#          9,  64, 243, 151, 187, 208, 210, 123, 267,  76, 286, 218, 272,
#        105, 293,  63, 158,   2, 192,  31, 203,  75, 183,  11,  48, 143,
#        233, 295, 283, 212, 253, 157,  85, 279, 104, 268,  25,  55, 142,
#        109, 193,  44, 148, 222,  74,  29,   0, 235,  62, 292, 128, 219,
#        207, 263,  87, 174, 188, 121,  59, 244, 124, 209,  17, 294, 113,
#        260, 276, 204,  61,  92,  50, 234,  27, 110,  21, 284,  88, 103,
#        122, 167, 261, 127, 236, 194,  42, 224,  24,  41, 221,  34,  60,
#        154, 266, 240, 287,  12, 296, 171, 125,  40, 254, 108,  51,  66,
#        302, 100, 145, 252,  13,  91, 297, 239, 186,  39,  67, 132, 111,
#        165,  32, 256, 216,  94, 202, 117, 189,  53,  35, 238, 144, 245,
# ...

# %%
le.inverse_transform([ 49,  36, 231,  14, 161, 141,  54, 223, 241,   1, 101, 215,  57,
        30, 274, 220,   8, 150,  95, 282, 211,  16, 258,  22,   7, 133,
        68, 112, 163,  65, 271, 156, 232, 162,  10, 242, 116, 129, 250,
         9,  64, 243, 151, 187, 208, 210, 123, 267,  76, 286, 218, 272,
       105, 293,  63, 158,   2, 192,  31, 203,  75, 183,  11,  48, 143,
       233, 295, 283, 212, 253, 157,  85, 279, 104, 268,  25,  55, 142,
       109, 193,  44, 148, 222,  74,  29,   0, 235,  62, 292, 128, 219,
       207, 263,  87, 174, 188, 121,  59, 244, 124, 209,  17, 294, 113,
       260, 276, 204,  61,  92,  50, 234,  27, 110,  21, 284,  88, 103,
       122, 167, 261, 127, 236, 194,  42, 224,  24,  41, 221,  34,  60,
       154, 266, 240, 287,  12, 296, 171, 125,  40, 254, 108,  51,  66,
       302, 100, 145, 252,  13,  91, 297, 239, 186,  39,  67, 132, 111,
       165,  32, 256, 216,  94, 202, 117, 189,  53,  35, 238, 144, 245,
        58,  70, 160, 288, 251, 269, 155, 107, 262,  89,  23, 181, 289,
       139, 180,  93, 201, 114, 195, 249, 135, 136, 237,   3,  28, 196,
        98,   4,  33, 140, 115,  84, 118, 265, 230, 206,  77,  19, 298,
       259, 214, 291, 166, 247, 197, 137,   6,  99, 149, 190, 120,  56,
        73, 304, 173, 106,  15, 184,  38, 225, 228,  79, 126,  37,  52,
       205, 248, 270,  82, 134,  18, 273, 175,  86, 176, 303, 300,  20,
       185, 170, 257, 281,  81, 182, 280, 152, 164, 229,  97, 277, 217,
       169,  80, 278, 177, 226, 131, 130, 285, 255, 172,  78, 213, 299,
       275,  90, 200, 146,  72,  45,  47,  46, 246,  96, 138,   5, 290,
       179, 178, 227, 191, 198, 168,  83,  26, 199,  71, 147, 264, 102,
        43, 153, 301, 119, 159,  69])
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'ford pinto', 'plymouth satellite custom', 'ford torino 500',
#        'amc matador', 'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
# ...

# %%
#ip/op Creation 
ip = auto.drop('MPG',axis=1)
op = auto.MPG

# %%
ip.head()
# Out:
#    Cylinders  Displacements  Horsepower  Weight  Acceleration  ModelYear  \
# 0          8          307.0       130.0  3504.0          12.0         70
# 1          8          350.0       165.0  3693.0          11.5         70
# 2          8          318.0       150.0  3436.0          11.0         70
# 3          8          304.0       150.0  3433.0          12.0         70
# 4          8          302.0       140.0  3449.0          10.5         70
#
#    Origin  Car Name
# 0       1        49
# 1       1        36
# 2       1       231
# 3       1        14
# 4       1       161

# %%
op.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: MPG, dtype: float64

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(ip,op,test_size=0.2,random_state=5)

# %%
x_train
# Out:
#      Cylinders  Displacements  Horsepower  Weight  Acceleration  ModelYear  \
# 248          4           91.0        60.0  1800.0          16.4         78
# 42           8          383.0       180.0  4955.0          11.5         71
# 238          4           98.0        83.0  2075.0          15.9         77
# 127          6          232.0       100.0  2901.0          16.0         74
# 56           4           91.0        70.0  1955.0          20.5         71
# ..         ...            ...         ...     ...           ...        ...
# 73           8          307.0       130.0  4098.0          14.0         72
# 118          4          116.0        75.0  2158.0          15.5         73
# 189          8          304.0       120.0  3962.0          13.9         76
# 206          4          140.0        72.0  2565.0          13.6         76
# 355          4          107.0        75.0  2210.0          14.4         81
#
#      Origin  Car Name
# 248       3       171
# ...

# %%
#Standard Scaler Transform 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train = sc.fit_transform(x_train) 
x_test = sc.fit_transform(x_test)

# %%
#Linear Regression 
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(x_test)
pred
# Out:
# array([27.66124758, 32.44319215, 27.53688824, 24.29500211, 18.95649775,
#        24.16066777, 30.62623008, 30.77309014, 21.7340539 , 25.19999239,
#        24.70922477, 34.12954424, 24.16559529, 25.44113057, 32.11477423,
#         8.49474446, 34.71915168, 33.38072237, 11.97809686, 34.21932124,
#        27.5495913 , 28.36338666, 18.36179558, 22.70806366, 14.21036165,
#         6.77988772, 12.33266327, 27.99223532, 29.38370315, 13.12993881,
#        19.18797891, 26.00718704, 24.17375351,  9.71818494, 18.98271751,
#        11.26484769, 31.71548632, 28.90142516, 19.88607589, 22.40495414,
#        28.63060928, 16.66892779, 24.22914105, 33.95426048,  7.08095571,
#        24.60489547, 24.11088882, 25.34527415, 14.77596338, 13.49337719,
#        20.67620345, 28.11136391, 21.25443556, 31.77595963, 21.81396174,
#        19.72262677, 15.75201404, 30.82622128, 24.18989238, 23.05466544,
#        22.38002134, 31.84841341, 13.4066151 , 22.24102855, 24.17605278,
# ...

# %%
y_test
# Out:
# 340    25.8
# 325    44.3
# 117    29.0
# 50     28.0
# 286    17.6
#        ...
# 184    25.0
# 140    14.0
# 107    18.0
# 240    30.5
# 48     18.0
# Name: MPG, Length: 80, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test,pred)
r2 = r2_score(y_test,pred)

print("MSE :" , mse ) #error jitna kam model utna accurate hei #it just shows the error..
print("R2 Score: ",int(r2*100),'%')
# Out:
# MSE : 13.274128416191479
# R2 Score:  77 %

# %%
df = pd.DataFrame({'Y_Test':y_test,'Prediction':pred})
df
# Out:
#      Y_Test  Prediction
# 340    25.8   27.661248
# 325    44.3   32.443192
# 117    29.0   27.536888
# 50     28.0   24.295002
# 286    17.6   18.956498
# ..      ...         ...
# 184    25.0   23.704559
# 140    14.0   10.745796
# 107    18.0   20.775366
# 240    30.5   28.393504
# 48     18.0   17.670301
#
# [80 rows x 2 columns]

# %%
sns.lmplot(x = 'Y_Test',y = 'Prediction',data = df)
plt.show()
